# %% [markdown]
# <a name="begin"></a>

# %% [markdown]
# <h1>Выявление определяющих успешность игры закономерностей<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>План работы</a></span></li><li><span><a href="#Загрузка-и-изучение-данных" data-toc-modified-id="Загрузка-и-изучение-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Загрузка и изучение данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-названий-столбцов" data-toc-modified-id="Замена-названий-столбцов-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Замена названий столбцов</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Обработка пропусков</a></span><ul class="toc-item"><li><span><a href="#name" data-toc-modified-id="name-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>name</a></span></li><li><span><a href="#year_of_release" data-toc-modified-id="year_of_release-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>year_of_release</a></span></li><li><span><a href="#user_score" data-toc-modified-id="user_score-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>user_score</a></span></li><li><span><a href="#critic_score" data-toc-modified-id="critic_score-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>critic_score</a></span></li><li><span><a href="#rating" data-toc-modified-id="rating-5.2.5"><span class="toc-item-num">5.2.5&nbsp;&nbsp;</span>rating</a></span></li></ul></li><li><span><a href="#Преобразование-в-нужные-типы-данных" data-toc-modified-id="Преобразование-в-нужные-типы-данных-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Преобразование в нужные типы данных</a></span><ul class="toc-item"><li><span><a href="#user_score" data-toc-modified-id="user_score-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>user_score</a></span></li><li><span><a href="#year_of_release" data-toc-modified-id="year_of_release-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>year_of_release</a></span></li></ul></li><li><span><a href="#Подсчет-суммарных-продаж-во-всех-регионах" data-toc-modified-id="Подсчет-суммарных-продаж-во-всех-регионах-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Подсчет суммарных продаж во всех регионах</a></span></li><li><span><a href="#Проверка-дубликатов" data-toc-modified-id="Проверка-дубликатов-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проверка дубликатов</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Количество-игр-по-годам" data-toc-modified-id="Количество-игр-по-годам-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Количество игр по годам</a></span></li><li><span><a href="#Изменения-продаж-по-платформам" data-toc-modified-id="Изменения-продаж-по-платформам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Изменения продаж по платформам</a></span></li><li><span><a href="#Актуальные-данные-и-распределение-продаж" data-toc-modified-id="Актуальные-данные-и-распределение-продаж-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Актуальные данные и распределение продаж</a></span></li><li><span><a href="#Корреляция-продаж-с-оценками-на-примере-популярных-платформ" data-toc-modified-id="Корреляция-продаж-с-оценками-на-примере-популярных-платформ-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Корреляция продаж с оценками на примере популярных платформ</a></span><ul class="toc-item"><li><span><a href="#PS4" data-toc-modified-id="PS4-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>PS4</a></span></li><li><span><a href="#XOne" data-toc-modified-id="XOne-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>XOne</a></span></li><li><span><a href="#WiiU" data-toc-modified-id="WiiU-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>WiiU</a></span></li><li><span><a href="#PS3" data-toc-modified-id="PS3-6.4.4"><span class="toc-item-num">6.4.4&nbsp;&nbsp;</span>PS3</a></span></li><li><span><a href="#X360" data-toc-modified-id="X360-6.4.5"><span class="toc-item-num">6.4.5&nbsp;&nbsp;</span>X360</a></span></li></ul></li><li><span><a href="#Распределение-игр-по-жанрам" data-toc-modified-id="Распределение-игр-по-жанрам-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Распределение игр по жанрам</a></span></li></ul></li><li><span><a href="#Составление-портрета-пользователя-каждого-региона" data-toc-modified-id="Составление-портрета-пользователя-каждого-региона-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Составление портрета пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Топ-5-платформ-по-продажам-в-регионах" data-toc-modified-id="Топ-5-платформ-по-продажам-в-регионах-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Топ-5 платформ по продажам в регионах</a></span></li><li><span><a href="#Топ-5-жанров-по-продажам-в-регионах" data-toc-modified-id="Топ-5-жанров-по-продажам-в-регионах-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Топ-5 жанров по продажам в регионах</a></span></li><li><span><a href="#Распределение-продаж-в-зависимости-от-рейтинга-в-регионах" data-toc-modified-id="Распределение-продаж-в-зависимости-от-рейтинга-в-регионах-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Распределение продаж в зависимости от рейтинга в регионах</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-об-одинаковых-средних-пользовательских-рейтингах-Xbox-One-и-PC" data-toc-modified-id="Гипотеза-об-одинаковых-средних-пользовательских-рейтингах-Xbox-One-и-PC-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Гипотеза об одинаковых средних пользовательских рейтингах Xbox One и PC</a></span></li><li><span><a href="#Гипотеза-о-разных-средних-пользовательских-рейтингах-жанров-Action-и-Sports" data-toc-modified-id="Гипотеза-о-разных-средних-пользовательских-рейтингах-жанров-Action-и-Sports-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Гипотеза о разных средних пользовательских рейтингах жанров Action и Sports</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Из открытых источников доступны исторические данные интернет-магазина «Стримчик», который продаёт по всему миру компьютерные игры, о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Предоставлены данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ## Описание данных

# %% [markdown]
# * ***Name*** — название игры
# * ***Platform*** — платформа
# * ***Year_of_Release*** — год выпуска
# * ***Genre*** — жанр игры
# * ***NA_sales*** — продажи в Северной Америке (миллионы проданных копий)
# * ***EU_sales*** — продажи в Европе (миллионы проданных копий)
# * ***JP_sales*** — продажи в Японии (миллионы проданных копий)
# * ***Other_sales*** — продажи в других странах (миллионы проданных копий)
# * ***Critic_Score*** — оценка критиков (максимум 100)
# * ***User_Score*** — оценка пользователей (максимум 10)
# * ***Rating*** — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ## План работы

# %% [markdown]
# 1. Загрузка и изучение данных
# 2. Предобработка данных
# 3. Исследовательский анализ данных
# 4. Составление портрета пользователя каждого региона
# 5. Проверка гипотез
# 6. Общий вывод

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ## Загрузка и изучение данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %%
# установка настроек вывода
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
# загрузка данных
df = pd.read_csv('/datasets/games.csv')

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii         2,006.00        Sports
# 1          Super Mario Bros.      NES         1,985.00      Platform
# 2             Mario Kart Wii      Wii         2,008.00        Racing
# 3          Wii Sports Resort      Wii         2,009.00        Sports
# 4   Pokemon Red/Pokemon Blue       GB         1,996.00  Role-Playing
# 5                     Tetris       GB         1,989.00        Puzzle
# 6      New Super Mario Bros.       DS         2,006.00      Platform
# 7                   Wii Play      Wii         2,006.00          Misc
# 8  New Super Mario Bros. Wii      Wii         2,009.00      Platform
# 9                  Duck Hunt      NES         1,984.00       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45         76.00          8      E
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        Year_of_Release  NA_sales  EU_sales  JP_sales  Other_sales  \
# count        16,446.00 16,715.00 16,715.00 16,715.00    16,715.00
# mean          2,006.48      0.26      0.15      0.08         0.05
# std               5.88      0.81      0.50      0.31         0.19
# min           1,980.00      0.00      0.00      0.00         0.00
# 25%           2,003.00      0.00      0.00      0.00         0.00
# 50%           2,007.00      0.08      0.02      0.00         0.01
# 75%           2,010.00      0.24      0.11      0.04         0.03
# max           2,016.00     41.36     28.96     10.22        10.57
#
#        Critic_Score
# count      8,137.00
# mean          68.97
# std           13.94
# min           13.00
# 25%           60.00
# 50%           71.00
# 75%           79.00
# max           98.00

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# **Вывод по разделу:**
#
# Загруженные данные имеют пропуски в столбцах: *Name, Year_of_Release, Critic_Score, User_Score, Rating*.
#
# Столбцы следует переименовать по стандарту, некоторым изменить тип данных.
#
# Следует проверить на наличие дубликатов.
#
# Есть большие разбросы между максимальными значениями и третьими квартилями в столбцах с продажами.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Замена названий столбцов

# %%
# приводим все названия столюцов к нижнему регистру
df.columns = df.columns.str.lower()
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii         2,006.00        Sports     41.36
# 1         Super Mario Bros.      NES         1,985.00      Platform     29.08
# 2            Mario Kart Wii      Wii         2,008.00        Racing     15.68
# 3         Wii Sports Resort      Wii         2,009.00        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB         1,996.00  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45         76.00          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29         82.00        8.3      E
# 3     10.93      3.28         2.95         80.00          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Обработка пропусков

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(df)

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### name

# %%
df.loc[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN         1,993.00   NaN      1.78      0.53      0.00
# 14244  NaN      GEN         1,993.00   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
# удаляем те данные, в которых пропущены название игры
df = df.dropna(subset=['name'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### year_of_release

# %%
# количество пропусков в столбце
df['year_of_release'].isna().sum()
# Out:
# 269

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# Пропуски в этом столбце могли появиться из-за ошибки системы, либо человеческого фактора.

# %%
df.loc[df['year_of_release'].isna(),'name'].value_counts()
# Out:
# LEGO Harry Potter: Years 5-7                                          7
# Happy Feet Two                                                        4
# Rock Band                                                             4
# WRC: FIA World Rally Championship                                     3
# Test Drive Unlimited 2                                                3
# Bejeweled 3                                                           3
# Battle vs. Chess                                                      2
# NBA Live 2003                                                         2
# Rock Revolution                                                       2
# Combat Elite: WWII Paratroopers                                       2
# Virtua Quest                                                          2
# Silent Hill: Homecoming                                               2
# The Lord of the Rings: War in the North                               2
# ...

# %%
df.loc[df['year_of_release'].isna(), 'platform'].value_counts()
# Out:
# PS2     34
# Wii     34
# DS      30
# X360    30
# PS3     25
# XB      21
# 2600    17
# PC      17
# PSP     16
# GC      14
# GBA     11
# 3DS      8
# PS       7
# N64      3
# PSV      1
# GB       1
# Name: platform, dtype: int64

# %%
# жизненный срок платформы
years_of_life = df.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life
# Out:
#               min      max  years_of_life
# platform
# 2600     1,980.00 1,989.00           9.00
# 3DO      1,994.00 1,995.00           1.00
# 3DS      2,011.00 2,016.00           5.00
# DC       1,998.00 2,008.00          10.00
# DS       1,985.00 2,013.00          28.00
# GB       1,988.00 2,001.00          13.00
# GBA      2,000.00 2,007.00           7.00
# GC       2,001.00 2,007.00           6.00
# GEN      1,990.00 1,994.00           4.00
# GG       1,992.00 1,992.00           0.00
# N64      1,996.00 2,002.00           6.00
# NES      1,983.00 1,994.00          11.00
# NG       1,993.00 1,996.00           3.00
# PC       1,985.00 2,016.00          31.00
# PCFX     1,996.00 1,996.00           0.00
# PS       1,994.00 2,003.00           9.00
# PS2      2,000.00 2,011.00          11.00
# PS3      2,006.00 2,016.00          10.00
# PS4      2,013.00 2,016.00           3.00
# PSP      2,004.00 2,015.00          11.00
# PSV      2,011.00 2,016.00           5.00
# ...

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# Большинство пропусков относится к платформам старого поколения. Данные о них не считаются актуальными, поэтому все пропуски можно удалить.

# %%
df = df.dropna(subset=['year_of_release'])

# %%
# жизненный срок платформы
years_of_life = df.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life
# Out:
#               min      max  years_of_life
# platform
# 2600     1,980.00 1,989.00           9.00
# 3DO      1,994.00 1,995.00           1.00
# 3DS      2,011.00 2,016.00           5.00
# DC       1,998.00 2,008.00          10.00
# DS       1,985.00 2,013.00          28.00
# GB       1,988.00 2,001.00          13.00
# GBA      2,000.00 2,007.00           7.00
# GC       2,001.00 2,007.00           6.00
# GEN      1,990.00 1,994.00           4.00
# GG       1,992.00 1,992.00           0.00
# N64      1,996.00 2,002.00           6.00
# NES      1,983.00 1,994.00          11.00
# NG       1,993.00 1,996.00           3.00
# PC       1,985.00 2,016.00          31.00
# PCFX     1,996.00 1,996.00           0.00
# PS       1,994.00 2,003.00           9.00
# PS2      2,000.00 2,011.00          11.00
# PS3      2,006.00 2,016.00          10.00
# PS4      2,013.00 2,016.00           3.00
# PSP      2,004.00 2,015.00          11.00
# PSV      2,011.00 2,016.00           5.00
# ...

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### user_score

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# Аббревиатура tdb - 'To Be Determined' - 'Будет определено'. По сути те же пропуски.

# %%
df['user_score'] = df['user_score'].replace('tbd',np.nan)
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### critic_score

# %%
df['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### rating

# %%
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# * **EC** - «Для детей младшего возраста»: Игра подходит для детей от 3 лет и не содержит материалов, которые родители могли бы счесть неподходящими. Продукты, получившие данный рейтинг, изначально разрабатываются для детей и обычно представляют собой развивающие игры.
# * **E** - «Для всех»: Содержание вполне подходит для всех возрастов. Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первоначально "K-A" ("Kids to Adults")
# * **E10+** - «Для всех от 10 лет и старше»: Проекты с данным рейтингом могут содержать больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови.
# * **T** - «Подросткам»: Игра подходит для лиц от 13 лет.
# * **M** - «Для взрослых»: Материалы игры не подходят для лиц младше 17 лет.
# * **AO** - «Только для взрослых»: Содержание игры только для взрослых старше 18 лет. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое.
# * **RP** - «Рейтинг ожидается»: Продукт был отправлен в ESRB и ожидает присвоения рейтинга.

# %%
# замена К-А на Е, т.к. это одна и та же возрастная категория
df.loc[df['rating']=='K-A', 'rating'] = 'E'

# %%
df.genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# Заполнять пропуски в оценках медианными или средними значениями нецелесообразно, так как их слишком много. Пропуски в рейтинге ESRB тоже просто так не заполнить, мы не знаем содержимого всех этих игр. Например, игры жанра "шутер" могут быть как мультяшными, так и реалистичными. Все эти пропуски могли возникнуть по причине позднего появления оценочной системы (например, игра вышла раньше, чем появилась платформа с оценками) или неполадок в системе.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Преобразование в нужные типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   object
#  10  rating           9768 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# #### user_score

# %%
df['user_score'] = df['user_score'].astype('float')

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### year_of_release

# %%
df['year_of_release'] = df['year_of_release'].astype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int16
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int16(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Подсчет суммарных продаж во всех регионах

# %%
df['sum_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)
df.sample(10)
# Out:
#                                         name platform  year_of_release  \
# 6535   Atelier Ayesha: The Alchemist of Dusk      PS3             2012
# 740                Pro Yakyuu Family Stadium      NES             1986
# 8961                Tom Clancy's Ghost Recon       GC             2003
# 14479       Emergency! Disaster Rescue Squad       DS             2009
# 7783              101-in-1 Explosive Megamix       DS             2008
# 14554                     Super Collapse! II      GBA             2004
# 5728                    Bust-A-Move Universe      3DS             2011
# 6485               Major League Baseball 2K9      Wii             2009
# 976                          The Evil Within      PS4             2014
# 4475                  007: Quantum of Solace      PS2             2008
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 6535   Role-Playing      0.06      0.04      0.14         0.02         70.00
# ...

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Проверка дубликатов

# %%
# приводим категориальные столбцы к нижнему регистру
df['name'] = df['name'].str.lower()
df['platform'] = df['platform'].str.lower()
df['genre'] = df['genre'].str.lower()
df.sample(10)
# Out:
#                               name platform  year_of_release         genre  \
# 11446                slayers royal       ps             1998  role-playing
# 12649  backyard skateboarding 2006      gba             2004        sports
# 8977        guilty gear x2 #reload       xb             2004      fighting
# 196                 guitar hero ii      ps2             2006          misc
# 11664               nhl hitz 20-03       gc             2002        sports
# 10503             death by degrees      ps2             2005        action
# 6311              sengoku basara 4      ps3             2014        action
# 2751      rhythm heaven: the best+      3ds             2015          misc
# 3054             100 classic books       ds             2008          misc
# 3549             breath of fire iv       ps             2000  role-playing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
df['platform'].unique()
# Out:
# array(['wii', 'nes', 'gb', 'ds', 'x360', 'ps3', 'ps2', 'snes', 'gba',
#        'ps4', '3ds', 'n64', 'ps', 'xb', 'pc', '2600', 'psp', 'xone',
#        'wiiu', 'gc', 'gen', 'dc', 'psv', 'sat', 'scd', 'ws', 'ng', 'tg16',
#        '3do', 'gg', 'pcfx'], dtype=object)

# %%
df[['name', 'platform', 'year_of_release']].duplicated().sum()
# Out:
# 1

# %%
# удаляем неявные дубликаты
df = df.drop_duplicates(subset=['name', 'platform', 'year_of_release'])

# %%
df[['name', 'platform', 'year_of_release']].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# **Вывод по разделу:**
#
# Заменены названия столбцов, обработаны пропуски, данные приведены к нужным типам. Добален стобец с суммарными продажами во всех регионах.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Количество игр по годам

# %%
df['year_of_release'].sort_values().unique()
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016], dtype=int16)

# %%
df['year_of_release'].nunique()
# Out:
# 37

# %%
df['year_of_release'].value_counts()
# Out:
# 2008    1427
# 2009    1426
# 2010    1255
# 2007    1197
# 2011    1136
# 2006    1006
# 2005     939
# 2002     829
# 2003     775
# 2004     762
# 2012     652
# 2015     606
# 2014     581
# 2013     544
# 2016     502
# 2001     482
# 1998     379
# 2000     350
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1983      17
# 1989      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# Name: year_of_release, dtype: int64

# %%
df['year_of_release'].hist(bins=37,figsize=(16,7), xrot=45)
plt.yticks(range(0,1501,100))
plt.xticks(range(1980,2017,1))
plt.title('Количество игр по годам', fontsize=16)
plt.xlabel('Год выпуска')
plt.ylabel('Количество выпущенных игр');

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# По графику видно, что после 1990 г. количество выпускаемых игр стало расти, вплоть до 2008 г., после пошел спад. Возможно этот спад связан с развитием мобильных устройств, которые составили серьезную конкуренцию, например, портативным консолям. Из-за этого одна и та же игра стала выходить на меньшее количество устройств.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Изменения продаж по платформам

# %%
df['platform'].value_counts().plot(kind='bar',figsize=(16,8), grid=True, rot=45)
plt.title('Количество выпущенных игр для каждой платформы', fontsize=16);

# %%
most_popular_pf = df.groupby('platform')['sum_sales'].agg('sum').sort_values(ascending=False).head()
print('Топ-5 наибольших суммарных продаж:')
most_popular_pf
# Out:
# Топ-5 наибольших суммарных продаж:
# platform
# ps2    1,233.56
# x360     961.24
# ps3      931.33
# wii      891.18
# ds       802.78
# Name: sum_sales, dtype: float64

# %%
df_platform = df.query('platform in @most_popular_pf.index and year_of_release >= 1999')
df_platform_pivot = df_platform.pivot_table(index='year_of_release', columns='platform', values='sum_sales',aggfunc='sum')
df_platform_pivot.plot(figsize=(15,10), grid=True, rot=45)
plt.title('Суммарные продажи игр по годам для 5 популярнейших платформ', fontsize=16)
plt.yticks(range(0,251,25))
plt.xticks(range(1998,2017,1))
plt.xlabel('Год выпуска')
plt.ylabel('Продажи (миллионы проданных копий)');

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# Судя по графикам, можно заметить, что примернный период жизни популярной платформы составляет 9-11 лет. Эти платформы начинают терять популярность спустя 4-6 лет. Примерно с этим же периодом появляются новые.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Актуальные данные и распределение продаж

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# У нас последние данные за 2016 г., платформы появляются с интервалом примерно 4-6. Для целей прогнозирования продаж на следующий год берем данные за последние 2-3 года.

# %%
df_actual = df.loc[df['year_of_release'] >= 2013]
df_actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2233 entries, 16 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2233 non-null   object
#  1   platform         2233 non-null   object
#  2   year_of_release  2233 non-null   int16
#  3   genre            2233 non-null   object
#  4   na_sales         2233 non-null   float64
#  5   eu_sales         2233 non-null   float64
#  6   jp_sales         2233 non-null   float64
#  7   other_sales      2233 non-null   float64
#  8   critic_score     991 non-null    float64
#  9   user_score       1192 non-null   float64
#  10  rating           1256 non-null   object
#  11  sum_sales        2233 non-null   float64
# dtypes: float64(7), int16(1), object(4)
# memory usage: 213.7+ KB

# %%
df_actual['platform'].value_counts()
# Out:
# ps4     392
# psv     358
# ps3     345
# 3ds     303
# xone    247
# pc      189
# x360    186
# wiiu    115
# psp      67
# wii      23
# ds        8
# Name: platform, dtype: int64

# %%
df_actual_pivot = df_actual.pivot_table(index='year_of_release', columns='platform', values='sum_sales',aggfunc='sum')
plt.figure(figsize=(16,10))
sns.lineplot(data=df_actual_pivot)
plt.title('Суммарные продажи игр по годам на разных платформах', fontsize=16)
plt.grid(True)
plt.yticks(range(0,151,25))
plt.xticks(range(2013,2017,1))
plt.xlabel('Год выпуска')
plt.ylabel('Продажи (миллионы проданных копий)');

# %%
df_actual.groupby('platform')['sum_sales'].describe()
# Out:
#           count  mean  std  min  25%  50%  75%   max
# platform
# 3ds      303.00  0.47 1.38 0.01 0.04 0.09 0.28 14.60
# ds         8.00  0.19 0.17 0.03 0.07 0.15 0.25  0.51
# pc       189.00  0.21 0.35 0.01 0.03 0.08 0.23  3.05
# ps3      345.00  0.53 1.45 0.01 0.04 0.15 0.51 21.05
# ps4      392.00  0.80 1.61 0.01 0.06 0.20 0.73 14.63
# psp       67.00  0.05 0.06 0.01 0.01 0.02 0.07  0.24
# psv      358.00  0.09 0.15 0.01 0.02 0.04 0.11  1.96
# wii       23.00  0.59 0.92 0.01 0.04 0.18 0.76  3.58
# wiiu     115.00  0.56 1.04 0.01 0.06 0.20 0.60  7.09
# x360     186.00  0.74 1.66 0.01 0.08 0.27 0.80 16.27
# xone     247.00  0.65 1.04 0.01 0.06 0.22 0.69  7.39

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df_actual, x='sum_sales', y='platform')
plt.grid(True)
plt.xlabel('Продажи (миллионы проданных копий)')
plt.ylabel('Платформы')
plt.title('Распределения продаж', fontsize=16);

# %%
# рассмотрим подробнее продажи до 2,5
plt.figure(figsize=(16,8))
sns.boxplot(data=df_actual.loc[df_actual['sum_sales']<=2.5], x='sum_sales', y='platform')
plt.grid(True)
plt.xlabel('Продажи (миллионы проданных копий)')
plt.ylabel('Платформы')
plt.title('Распределения продаж', fontsize=16);

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# С момента выхода PS4 и XOne в 2013 г., все остальные платформы начали серьезно терять в продажах.
#
# У некоторых платформ есть несколько проектов с очень большими количествами продаж. Если сравнивать платформы нового поколения, то PS4 в этом плане превосходит XOne. Но, если сравнивать медианные значения и межквартильные размахи, то XOne фаворит. Эти две платформы потенциально могут быть прибыльными в 2017 г., так как они из нового поколения, имеют хорошие показатели про продажам игр и могут продержаться ещё 3 года. Также стоит обратить внимание на X360, Wii, WiiU, PS3.
#
# В 2016 г. есть провал в продажах. Возможно, это связано с тем, что данные даны не за весь 2016 г.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Корреляция продаж с оценками на примере популярных платформ

# %%
# функция проверки корреляции для определенной платформы
def platform_corr(platform):
    pd.plotting.scatter_matrix(df_actual.loc[df_actual['platform']==platform, 
                                         ['sum_sales','critic_score','user_score']],
                           figsize=(17,12))
    plt.show();
    display(df_actual.loc[df_actual['platform']==platform, ['sum_sales','critic_score','user_score']].corr())

# %% [markdown]
# #### PS4

# %%
platform_corr('ps4')
# Out:
#               sum_sales  critic_score  user_score
# sum_sales          1.00          0.41       -0.03
# critic_score       0.41          1.00        0.56
# user_score        -0.03          0.56        1.00

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### XOne

# %%
platform_corr('xone')
# Out:
#               sum_sales  critic_score  user_score
# sum_sales          1.00          0.42       -0.07
# critic_score       0.42          1.00        0.47
# user_score        -0.07          0.47        1.00

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### WiiU

# %%
platform_corr('wiiu')
# Out:
#               sum_sales  critic_score  user_score
# sum_sales          1.00          0.38        0.42
# critic_score       0.38          1.00        0.72
# user_score         0.42          0.72        1.00

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### PS3

# %%
platform_corr('ps3')
# Out:
#               sum_sales  critic_score  user_score
# sum_sales          1.00          0.33        0.00
# critic_score       0.33          1.00        0.60
# user_score         0.00          0.60        1.00

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# #### X360

# %%
platform_corr('x360')
# Out:
#               sum_sales  critic_score  user_score
# sum_sales          1.00          0.35       -0.01
# critic_score       0.35          1.00        0.52
# user_score        -0.01          0.52        1.00

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# Как выяснилось, на продажи **возможно** немного влияют отзывы критиков и практически не влияют отзывы пользователей. Это связано с тем, что пользователи в основном выставляют оценку после покупки игры. Критики, как правило, имеют ранний доступ к игре, поэтому покупатели больше смотрят на их мнение. Отзывы покупателей средне коррелируют с отзывами критиков.
#
# Возможно, пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках проекта.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Распределение игр по жанрам

# %%
df_actual['genre'].value_counts().plot(kind='bar', figsize=(14,7), rot=45, grid=True)
plt.title('Количество игр в каждом жанре', fontsize=16)
plt.xlabel('Жанр')
plt.ylabel('Количество игр');

# %%
(df_actual.groupby('genre')['sum_sales']
 .agg('sum').sort_values(ascending=False)
 .plot(kind='bar', figsize=(14,7), rot=45, grid=True))
plt.title('Количество проданных игр в каждом жанре', fontsize=16)
plt.xlabel('Жанр')
plt.ylabel('Количество проданных игр');

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df_actual, x='sum_sales', y='genre')
plt.grid(True)
plt.xlabel('Продажи (миллионы проданных копий)')
plt.ylabel('Жанры')
plt.title('Диаграмма размаха проданных игр в каждом жанре', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Диаграмма размаха проданных игр в каждом жанре')

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df_actual, x='sum_sales', y='genre')
plt.grid(True)
plt.xlim(0,3.5)
plt.xlabel('Продажи (миллионы проданных копий)')
plt.ylabel('Жанры')
plt.title('Диаграмма размаха проданных игр в каждом жанре', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Диаграмма размаха проданных игр в каждом жанре')

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# По графику количества продаж по жанрам можно скзать, что:
# * Самый популярный жанр и распространенный жанр - "Action".
# * Хорошие показатели продаж у жанров "Shooter", "Sport", "Role-Playing", "Misc".
# * Худшие показатели продаж у жанров "Strategy" и "Puzzle". Эти же жанры имеют малое количество проектов, по-сравнению с другими.
#
# Но, если посмотреть на диаграмму размаха, то станет ясно, что большая средняя успешность у жанров "Shooter", "Sport", "Platform". Жанр "Action" в среднем гораздо реже добивается успеха. "Strategy" и "Puzzle" также в аутсайдерах.

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# **Вывод по разделу:**
#
# * После 2008 г. пошел спад количества выпускаемых игр. Он связан с уменьшением количества платформ, а таккже, возможно, с развитием мобильных устройств.
# * Примернный период жизни популярной платформы составляет 9-11 лет. Эти платформы начинают терять популярность спустя 4-6 лет. Примерно с этим же периодом появляются новые.
# * С момента выхода PS4 и XOne в 2013 г., все остальные платформы начали серьезно терять в продажах. Эти две платформы потенциально могут быть прибыльными в 2017 г., так как они из нового поколения, имеют хорошие показатели про продажам игр и могут продержаться ещё 3 года. Также стоит обратить внимание на X360, Wii, WiiU, PS3.
# * Согласно коэффициенту корреляции, на продажи немного влияют отзывы критиков и практически не влияют отзывы пользователей. Возможно, пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках проекта.
# * Самый популярный и распространенный жанр - "Action". Но лучшие средние показатели продаж у жанров "Shooter", "Sport", "Platform". Худшие показатели продаж у жанров "Strategy" и "Puzzle". Эти же жанры имеют малое количество проектов, по-сравнению с другими.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ## Составление портрета пользователя каждого региона

# %%
df_actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2233 entries, 16 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2233 non-null   object
#  1   platform         2233 non-null   object
#  2   year_of_release  2233 non-null   int16
#  3   genre            2233 non-null   object
#  4   na_sales         2233 non-null   float64
#  5   eu_sales         2233 non-null   float64
#  6   jp_sales         2233 non-null   float64
#  7   other_sales      2233 non-null   float64
#  8   critic_score     991 non-null    float64
#  9   user_score       1192 non-null   float64
#  10  rating           1256 non-null   object
#  11  sum_sales        2233 non-null   float64
# dtypes: float64(7), int16(1), object(4)
# memory usage: 278.2+ KB

# %%
# создаем сводную таблицу продаж по платформам по регионам
reg_sales_pf = df_actual.pivot_table(index='platform', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
reg_sales_pf
# Out:
#           eu_sales  jp_sales  na_sales
# platform
# 3ds          30.96     67.81     38.20
# ds            0.85      0.00      0.57
# pc           25.36      0.00     11.11
# ps3          67.81     23.35     63.50
# ps4         141.09     15.96    108.74
# psp           0.17      3.29      0.00
# psv           6.10     18.59      5.04
# wii           5.93      0.05      6.56
# wiiu         19.85     10.88     29.21
# x360         42.52      0.51     81.66
# xone         51.59      0.34     93.12

# %%
# создаем сводную таблицу продаж по жанрам по регионам
reg_sales_genre = df_actual.pivot_table(index='genre', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
reg_sales_genre
# Out:
#               eu_sales  jp_sales  na_sales
# genre
# action          118.13     40.49    126.05
# adventure         8.25      5.82      7.14
# fighting          8.55      7.65     15.55
# misc             20.04      9.20     27.49
# platform         15.58      4.79     18.14
# puzzle            1.00      1.18      0.83
# racing           20.19      2.30     12.96
# role-playing     36.97     51.04     46.40
# shooter          87.86      6.61    109.74
# simulation       10.92      4.52      4.86
# sports           60.52      5.41     65.27
# strategy          4.22      1.77      3.28

# %%
# создаем сводную таблицу продаж по рейтингу по регионам
reg_sales_rating = df_actual.pivot_table(index='rating', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
reg_sales_rating
# Out:
#         eu_sales  jp_sales  na_sales
# rating
# E          83.36     15.14     79.05
# E10+       42.69      5.89     54.24
# M         145.32     14.11    165.21
# T          41.95     20.59     49.79

# %%
def reg_sales_pct(reg_sales,col):
    df_pct = reg_sales[col].sort_values(ascending=False)[:5]
    df_pct = df_pct.append(pd.Series({'Other' : reg_sales[col].sort_values(ascending=False)[5:].sum()}))
    return df_pct

# %% [markdown]
# ### Топ-5 платформ по продажам в регионах

# %%
plt.figure(figsize=(17, 6))
plt.suptitle('Топ-5 платформ по продажам в регионах', fontsize=16)
plt.subplot(1,3,1)
reg_sales_pct(reg_sales_pf,'eu_sales').plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('EU')
plt.subplot(1,3,2)
reg_sales_pct(reg_sales_pf,'jp_sales').plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('JP')
plt.subplot(1,3,3)
reg_sales_pct(reg_sales_pf,'na_sales').plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('NA');

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Топ-5 жанров по продажам в регионах

# %%
plt.figure(figsize=(17, 6))
plt.suptitle('Топ-5 жанров по продажам в регионах', fontsize=16)
plt.subplot(1,3,1)
reg_sales_pct(reg_sales_genre,'eu_sales').plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('EU')
plt.subplot(1,3,2)
reg_sales_pct(reg_sales_genre,'jp_sales').plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('JP')
plt.subplot(1,3,3)
reg_sales_pct(reg_sales_genre,'na_sales').plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('NA');

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Распределение продаж в зависимости от рейтинга в регионах

# %%
plt.figure(figsize=(17, 6))
plt.suptitle('Распределение продаж в зависимости от рейтинга в регионах', fontsize=16)
plt.subplot(1,3,1)
reg_sales_rating['eu_sales'].plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('EU')
plt.subplot(1,3,2)
reg_sales_rating['jp_sales'].plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('JP')
plt.subplot(1,3,3)
reg_sales_rating['na_sales'].plot(kind='pie', ylabel='', autopct='%1.2f%%')
plt.title('NA');

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# **Вывод по разделу:**
#
# * Самая популярная платформа в:
#     * EU - PS4 (35,97%)
#     * JP - 3DS (48,17%)
#     * NA - PS4 (24,84%)
# * Самая популярная платформа нового поколения в:
#     * EU - PS4 (35,97%) / XOne (13,15%)
#     * JP - PS4 (11,34%) / XOne (&mdash;)
#     * NA - PS4 (24,84%) / XOne (21,27%)
# * Самый популярный жанр в:
#     * EU - Action (30,12%)
#     * JP - Role-Playing (36,26%)
#     * NA - Action (28,80%)
# * Самый популярный рейтинг в:
#     * EU - M (46,38%)
#     * JP - T (36,95%)
#     * NA - M (47,43%)
#
# У Европы и Северной Америки, в целом, похожие взгляды на игры (жанры, рейтинг) и платформы. В Японии же популярны другие жанры и платформы, также это более консервативная страна, которая не стремится переходить на консоли нового поколения.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, значительное влияние на портрет оказывает период с 2009 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
#
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза об одинаковых средних пользовательских рейтингах Xbox One и PC

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# $H_0$: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# $H_1$: Средние пользовательские рейтинги платформ Xbox One и PC отличаются.

# %%
# пользовательские рейтинги PS4
ps4 = df_actual.loc[(df_actual['platform'] == 'ps4') & (~(df_actual['user_score'].isna())), 'user_score']
len(ps4)
# Out:
# 257

# %%
# пользовательские рейтинги XOne
xone = df_actual.loc[(df_actual['platform'] == 'xone') & (~(df_actual['user_score'].isna())), 'user_score']
len(xone)
# Out:
# 182

# %%
# проверка дат в актуальной df_actual
years_of_life = df_actual.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life.loc[(years_of_life.index=='ps4') | ((years_of_life.index=='xone'))]
# Out:
#            min   max  years_of_life
# platform
# ps4       2013  2016              3
# xone      2013  2016              3

# %%
# проверка дат в старой df
years_of_life = df.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life.loc[(years_of_life.index=='ps4') | ((years_of_life.index=='xone'))]
# Out:
#            min   max  years_of_life
# platform
# ps4       2013  2016              3
# xone      2013  2016              3

# %%
res = st.ttest_ind(ps4, xone, equal_var=False)
alpha = 0.05
print('Вероятность получить наблюдаемый результат при условии, что нулевая гипотеза верна (p-value):', res.pvalue)
if res.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# Вероятность получить наблюдаемый результат при условии, что нулевая гипотеза верна (p-value): 0.09855299487302606
# Нет оснований отвергнуть нулевую гипотезу

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ### Гипотеза о разных средних пользовательских рейтингах жанров Action и Sports

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# $H_0$: Средние пользовательские рейтинги  жанров Action и Sports одинаковые.
#
# $H_1$: Средние пользовательские рейтинги  жанров Action и Sports отличаются.

# %%
df_actual['genre'].unique()
# Out:
# array(['action', 'shooter', 'role-playing', 'misc', 'sports', 'fighting',
#        'racing', 'simulation', 'platform', 'strategy', 'adventure',
#        'puzzle'], dtype=object)

# %%
# пользовательские рейтинги жанра Action
g_action = df_actual.loc[(df_actual['genre'] == 'action') & (~(df_actual['user_score'].isna())), 'user_score']
len(g_action)
# Out:
# 389

# %%
# пользовательские рейтинги жанра Sports
g_sports = df_actual.loc[(df_actual['genre'] == 'sports') & (~(df_actual['user_score'].isna())), 'user_score']
len(g_sports)
# Out:
# 160

# %%
res = st.ttest_ind(g_action, g_sports, equal_var=False)
alpha = 0.05
print('Вероятность получить наблюдаемый результат при условии, что нулевая гипотеза верна (p-value):', res.pvalue)
if res.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# Вероятность получить наблюдаемый результат при условии, что нулевая гипотеза верна (p-value): 1.4460039700704315e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# В выдвинутых гипотезах проверялись равенства средних двух генеральных совокупностей. Для этого использовался двусторонний t-тест, в котором выборки разного размера, поэтому применялся метод `scipy.stats.ttest_ind(array1, array2, equal_var=False, alternative='two-sided')`

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:left; padding:2%">
#
# **Вывод по разделу:**
#
# После проверок гипотез, получены следующие результаты:
#
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# * Средние пользовательские рейтинги жанров Action и Sports отличаются.

# %% [markdown]
# [В начало](#begin)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Количество выпускаемых в год игр падает. Это связано с тем, что уменьшается количество платформ, а также с развитием качества и технологичности игр, из-за чего требуется больше времени на разработку. У платформ с момента выпуска возрастает количество продаж в течение 4-6 лет, после идет падение.
#
# **Портреты пользователей:**
#
# * Самая популярная платформа в:
#     * EU - PS4 (35,97%)
#     * JP - 3DS (48,17%)
#     * NA - PS4 (24,84%)
# * Самая популярная платформа нового поколения в:
#     * EU - PS4 (35,97%) / XOne (13,15%)
#     * JP - PS4 (11,34%) / XOne (&mdash;)
#     * NA - PS4 (24,84%) / XOne (21,27%)
# * Самый популярный жанр в:
#     * EU - Action (30,12%)
#     * JP - Role-Playing (36,26%)
#     * NA - Action (28,80%)
# * Самый популярный рейтинг в:
#     * EU - M (46,38%)
#     * JP - T (36,95%)
#     * NA - M (47,43%)
#
# ***Рекомендации:***
# - Стоит обратить внимание на игры для платформ нового поколения - PS4 и XOne. Также стоит обратить внимание на X360, Wii, WiiU, PS3.
# - Рекомендуемые жанры: "Shooter", "Sport", "Platform". С жанром "Action" надо быть поаккуратнее, так как игр этого жанра много, но успешных мало.
# - Не стоит недооценивать влияние критиков. Их мнения немного влияют на продажи.

# %% [markdown]
# [В начало](#begin)
